# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None
    n1=node(10)
    n2=node(20)
    n3=node(30)

    n1.next=n2
    n2.next=n3
    head=n1

    def traversal(head):
        temp=head
        while temp:
            
            print(temp.data,end="->")
            temp=temp.next
        print("null")
    print(traversal(head))
# Out:
# 10->20->30->null
# None

# %%
def insertb(head,data):
    newnode=node(data)
    newnode.next=head
    return newnode
head=insertb(head,5)


print(traversal(head))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 8
#       4     return newnode
#       5 head=insertb(head,5)
# ----> 8 print(traversal(head))
#
# NameError: name 'traversal' is not defined

# %%
#Now Insert the element at the beginning:
def insertingatbeginning(head,data):
    newnode=node(data)
    newnode.next=head
    return newnode
head=insertingatbeginning(head,5)

print(traverse(head))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 8
#       5     return newnode
#       6 head=insertingatbeginning(head,5)
# ----> 8 print(traverse(head))
#
# NameError: name 'traverse' is not defined
